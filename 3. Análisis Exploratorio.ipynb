# %% [markdown]
# # 1. Importar librerías

# %%
import pandas as pd

from importlib import reload
import utils.utils as utils
reload(utils)  # Recarga el módulo
# Out:
# <module 'utils.utils' from 'c:\\Users\\USUARIO\\OneDrive - Universidad de Antioquia\\Aprendizaje\\Universidad\\2023-2\\Analítica II\\Caso Estudio No Supervisado\\no_supervisado\\utils\\utils.py'>

# %% [markdown]
# # 2. Importar base de datos

# %%
df = pd.read_csv('datasets/data_limpio.csv')

# %%
df.head()
# Out:
#    matriculados  registros  presentes  publicados  puntaje_global  \
# 0          66.0         66         64          63           240.0
# 1          31.0         31         29          29           238.0
# 2          73.0         73         73          73           232.0
# 3          38.0         38         38          38           246.0
# 4          81.0         81         79          78           247.0
#
#    puntaje_lectura  puntaje_matematicas  puntaje_sociales  puntaje_naturales  \
# 0             50.0                 49.0              48.0               46.0
# 1             49.0                 48.0              47.0               47.0
# 2             48.0                 46.0              47.0               45.0
# 3             53.0                 47.0              50.0               47.0
# 4             51.0                 49.0              50.0               48.0
#
#    puntaje_ingles  ... punt_sociales_sector punt_naturales_sector  \
# ...

# %% [markdown]
# # 3. Puntajes

# %%
cols_p = ['puntaje_lectura', 'puntaje_matematicas', 'puntaje_sociales', 'puntaje_naturales', 'puntaje_ingles']

# %%
utils.graficar_distribucion(df, cols_p)

# %%
df[cols_p].describe()
# Out:
#        puntaje_lectura  puntaje_matematicas  puntaje_sociales  \
# count      1657.000000          1657.000000       1657.000000
# mean         54.675317            52.561859         52.490042
# std           5.054971             6.334759          5.559846
# min          36.000000            29.000000         28.000000
# 25%          51.000000            48.000000         49.000000
# 50%          54.000000            51.000000         51.000000
# 75%          58.000000            56.000000         56.000000
# max          72.000000            85.000000         74.000000
#
#        puntaje_naturales  puntaje_ingles
# count        1657.000000     1657.000000
# mean           52.175015       54.027158
# std             5.708247        8.471741
# min            33.000000       31.000000
# 25%            48.000000       48.000000
# 50%            51.000000       52.000000
# 75%            55.000000       57.000000
# max           100.000000       94.000000

# %% [markdown]
# **Interpretación**
#
# ...

# %% [markdown]
# # 4. Año

# %%
utils.univariado_barras(df, 'año', 'v')
# Out:
#     año  Frecuencia Absoluta Frecuencia Relativa
# 3  2017                  339            20.459 %
# 1  2015                  334            20.157 %
# 2  2016                  333            20.097 %
# 4  2018                  328            19.795 %
# 0  2014                  323            19.493 %

# %% [markdown]
# **Interpretación**
#
# ...

# %% [markdown]
# # 5. Prestación servicio

# %%
utils.Analisisbivariado(df,['año', 'prestacion_servicio'],'v','group')
# Out:
# Tabla de contingencia:
# prestacion_servicio  contratacion   oficial   privado
# año
# 2014                     0.108359  0.634675  0.256966
# 2015                     0.122754  0.613772  0.263473
# 2016                     0.072072  0.657658  0.270270
# 2017                     0.088496  0.648968  0.262537
# 2018                     0.076220  0.670732  0.253049

# %% [markdown]
# **Interpretacion**
#
# ...

# %% [markdown]
# # 6. Comuna

# %%
tabla_comuna = utils.univariado_barras(df, 'comuna', 'v')
# Out:
#                   comuna  Frecuencia Absoluta Frecuencia Relativa
# 14               robledo                  166            10.018 %
# 5               castilla                  118             7.121 %
# 2               aranjuez                  116             7.001 %
# 3                  belen                  115              6.94 %
# 13               poblado                  111             6.699 %
# 11              manrique                  106             6.397 %
# 9          la candelaria                  102             6.156 %
# 4           buenos aires                  100             6.035 %
# 8             la america                   99             5.975 %
# 0                popular                   85              5.13 %
# 6        doce de octubre                   85              5.13 %
# 20         villa hermosa                   82             4.949 %
# 17            san javier                   59             3.561 %
# ...

# %% [markdown]
# **Interpretación**
#
# ...
